# %%
from pandas_datareader import DataReader
import datetime
import pandas as pd

# %%
start_date = datetime.date(2015, 1, 1)
end_date = datetime.date(2016, 12, 31)
now = datetime.datetime.now()
ticker = 'GOOG' 
data_source = "yahoo"

# %%
stock_data = DataReader(ticker, data_source, start_date, now)

# %%
stock_data
# Out:
#                   High         Low  ...      Volume   Adj Close
# Date                                ...
# 2014-12-31   26.557089   26.218018  ...  27364925.0   26.247936
# 2015-01-05   26.144720   25.582764  ...  41196796.0   25.623152
# 2015-01-21   25.892912   25.240702  ...  45374234.0   25.831081
# 2015-02-11   26.848787   26.595881  ...  27555446.0   26.725126
# 2015-02-12   27.166414   26.660454  ...  32404724.0   27.072172
# ...                ...         ...  ...         ...         ...
# 2022-10-03   99.970001   97.019997  ...  24840000.0   99.300003
# 2022-10-06  103.730003  101.500000  ...  17156200.0  102.239998
# 2022-10-25  105.099998  103.019997  ...  29910200.0  104.930000
# 2022-11-03   86.550003   83.449997  ...  48510400.0   83.489998
# 2022-11-04   86.730003   83.879997  ...  40155100.0   86.699997
#
# [469 rows x 6 columns]

# %%
stock_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 469 entries, 2014-12-31 to 2022-11-04
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   High       469 non-null    float64
#  1   Low        469 non-null    float64
#  2   Open       469 non-null    float64
#  3   Close      469 non-null    float64
#  4   Volume     469 non-null    float64
#  5   Adj Close  469 non-null    float64
# dtypes: float64(6)
# memory usage: 25.6 KB

# %%
pd.concat([stock_data.head(3), stock_data.tail(3)])
# Out:
#                   High         Low  ...      Volume   Adj Close
# Date                                ...
# 2014-12-31   26.557089   26.218018  ...  27364925.0   26.247936
# 2015-01-05   26.144720   25.582764  ...  41196796.0   25.623152
# 2015-01-21   25.892912   25.240702  ...  45374234.0   25.831081
# 2022-10-25  105.099998  103.019997  ...  29910200.0  104.930000
# 2022-11-03   86.550003   83.449997  ...  48510400.0   83.489998
# 2022-11-04   86.730003   83.879997  ...  40155100.0   86.699997
#
# [6 rows x 6 columns]

# %%
import matplotlib.pyplot as plt

stock_data['Close'].plot(title = ticker)
plt.show()

# %%
serie_code = 'DGS10' 
data_source = 'fred' 
start = datetime.date(1962, 1, 1)
data = DataReader(serie_code, data_source, start)

# %%
data
# Out:
#             DGS10
# DATE
# 1962-01-02   4.06
# 1962-01-03   4.03
# 1962-01-04   3.99
# 1962-01-05   4.02
# 1962-01-08   4.03
# ...           ...
# 2022-10-28   4.02
# 2022-10-31   4.10
# 2022-11-01   4.07
# 2022-11-02   4.10
# 2022-11-03   4.14
#
# [15873 rows x 1 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 15873 entries, 1962-01-02 to 2022-11-03
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   DGS10   15197 non-null  float64
# dtypes: float64(1)
# memory usage: 248.0 KB

# %%
series_name = '10-year Treasury' 
data = data.rename(columns={})
